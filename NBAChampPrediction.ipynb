# %%
# import the data and the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
NbaS = pd.read_csv("NBA.csv")
NbaS.head()
# Out:
#    Unnamed: 0                    TEAM  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0           1          Boston Celtics  40  31   9  0.775  48.6  121.0  43.2
# 1           2  Minnesota Timberwolves  39  28  11  0.718  48.3  113.1  41.0
# 2           3         Milwaukee Bucks  40  28  12  0.700  48.4  125.0  45.0
# 3           4   Oklahoma City Thunder  40  27  13  0.675  48.3  121.9  45.0
# 4           5          Denver Nuggets  42  28  14  0.667  48.0  116.3  44.4
#
#     FGA  ...  DREB   REB  AST   TOV  STL  BLK  BLKA    PF   PFD   PM
# 0  90.4  ...  36.5  47.4   26  13.0  6.5  6.4   4.0  17.5  19.1  9.8
# 1  84.1  ...  34.9  44.2   26  15.4  7.7  5.9   4.7  19.7  20.6  5.8
# 2  89.7  ...  34.8  44.4   27  13.2  6.5  5.5   4.5  20.3  20.5  5.0
# 3  89.2  ...  32.8  41.1   27  12.5  8.2  6.4   5.2  20.0  19.5  8.2
# 4  89.0  ...  33.0  43.8   30  12.6  7.1  5.3   5.0  19.0  18.8  5.0
#
# [5 rows x 28 columns]

# %%
# Test columns
teams = NbaS["TEAM"]
print(teams)
# Out:
# 0             Boston Celtics
# 1     Minnesota Timberwolves
# 2            Milwaukee Bucks
# 3      Oklahoma City Thunder
# 4             Denver Nuggets
# 5         Philadelphia 76ers
# 6                LA Clippers
# 7        Cleveland Cavaliers
# 8                 Miami Heat
# 9           Dallas Mavericks
# 10      New Orleans Pelicans
# 11            Indiana Pacers
# 12           New York Knicks
# 13          Sacramento Kings
# 14             Orlando Magic
# 15              Phoenix Suns
# 16                 Utah Jazz
# 17        Los Angeles Lakers
# 18           Houston Rockets
# 19             Chicago Bulls
# 20     Golden State Warriors
# 21             Atlanta Hawks
# 22             Brooklyn Nets
# 23         Memphis Grizzlies
# 24           Toronto Raptors
# 25    Portland Trail Blazers
# 26         Charlotte Hornets
# 27         San Antonio Spurs
# 28        Washington Wizards
# 29           Detroit Pistons
# Name: TEAM, dtype: object

# %%
Contenders = (NbaS[ NbaS["WIN%"] > 0.500 ] )
ContendingTeams = Contenders["TEAM"]
print(ContendingTeams)
# Out:
# 0             Boston Celtics
# 1     Minnesota Timberwolves
# 2            Milwaukee Bucks
# 3      Oklahoma City Thunder
# 4             Denver Nuggets
# 5         Philadelphia 76ers
# 6                LA Clippers
# 7        Cleveland Cavaliers
# 8                 Miami Heat
# 9           Dallas Mavericks
# 10      New Orleans Pelicans
# 11            Indiana Pacers
# 12           New York Knicks
# 13          Sacramento Kings
# 14             Orlando Magic
# 15              Phoenix Suns
# 16                 Utah Jazz
# Name: TEAM, dtype: object

# %%
ContendingTeams.plot()
plt.show()
